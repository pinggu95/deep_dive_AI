# %% [markdown]
# <a href="https://colab.research.google.com/github/pinggu95/deep_dive_AI/blob/main/57%EC%9D%BC%EC%B0%A8/57%EC%9D%BC%EC%B0%A8_bertopic_eng.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bertopic[visualization]
# Out:
# ...
# WARNING: bertopic 0.17.3 does not provide the extra 'visualization'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.0/153.0 kB 13.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 94.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 70.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 5.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# # 1. BERTopic

# %% [markdown]
# # 2. 데이터 로드

# %%
from bertopic import BERTopic
from sklearn.datasets import fetch_20newsgroups

# %%
docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']

# %%
# 상위 5개의 샘플 출력
docs[:5]
# Out:
# ["\n\nI am sure some bashers of Pens fans are pretty confused about the lack\nof any kind of posts about the recent Pens massacre of the Devils. Actually,\nI am  bit puzzled too and a bit relieved. However, I am going to put an end\nto non-PIttsburghers' relief with a bit of praise for the Pens. Man, they\nare killing those Devils worse than I thought. Jagr just showed you why\nhe is much better than his regular season stats. He is also a lot\nfo fun to watch in the playoffs. Bowman should let JAgr have a lot of\nfun in the next couple of games since the Pens are going to beat the pulp out of Jersey anyway. I was very disappointed not to see the Islanders lose the final\nregular season game.          PENS RULE!!!\n\n",
# ...

# %%
print('총 문서의 수 :', len(docs))
# Out:
# 총 문서의 수 : 18846

# %% [markdown]
# # 3. 토픽 모델링

# %%
model = BERTopic()
topics, probabilities = model.fit_transform(docs)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
print('각 문서의 토픽 번호 리스트 :',len(topics))
print('첫번째 문서의 토픽 번호 :', topics[0])
# Out:
# 각 문서의 토픽 번호 리스트 : 18846
# 첫번째 문서의 토픽 번호 : 0

# %%
# 각 토픽의 크기와 각 토픽에 할당된 단어들
model.get_topic_info()
# Out:
#      Topic  Count                                        Name  \
# 0       -1   6343                             -1_to_the_of_is
# 1        0   1841                        0_game_team_games_he
# 2        1    549               1_key_clipper_chip_encryption
# 3        2    531                       2_ites_hello_cheek_hi
# 4        3    468                  3_israel_israeli_jews_arab
# ..     ...    ...                                         ...
# 219    218     10  218_prophesies_revelation_jeremiah_babylon
# 220    219     10        219_religion_justifiable_war_history
# 221    220     10                 220_koresh_he_beliefs_david
# 222    221     10       221_portable_powerbook_backlit_memory
# 223    222     10               222_stuffit_files_system_disk
#
#                                         Representation  \
# 0       [to, the, of, is, and, for, it, in, you, that]
# 1    [game, team, games, he, players, season, hocke...
# ...

# %%
model.get_topic_info()['Count'].sum()
# Out:
# np.int64(18846)

# %%
model.get_topic(5)
# Out:
# [('dod', np.float64(0.01435858599197521)),
#  ('bike', np.float64(0.012595863583662695)),
#  ('riding', np.float64(0.010009080052166684)),
#  ('ride', np.float64(0.009778692184190014)),
#  ('my', np.float64(0.007481698547021848)),
#  ('lane', np.float64(0.006724919792768538)),
#  ('you', np.float64(0.006596330430218673)),
#  ('your', np.float64(0.005973257085005269)),
#  ('car', np.float64(0.005650908999856377)),
#  ('road', np.float64(0.005633493752606077))]

# %% [markdown]
# # 4. 토픽 시각화

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # 5. 단어 시각화

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # 6. 토픽 유사도 시각화

# %%
model.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # 7. 토픽의 수 정하기

# %%
model = BERTopic(nr_topics=20)
topics, probabilities = model.fit_transform(docs)

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model = BERTopic(nr_topics="auto")
topics, probabilities = model.fit_transform(docs)

# %%
# 각 토픽의 크기와 각 토픽에 할당된 단어들
model.get_topic_info()
# Out:
#      Topic  Count                                    Name  \
# 0       -1   6831                        -1_the_to_and_of
# 1        0   1835                    0_game_team_he_games
# 2        1   1328                        1_god_that_of_is
# 3        2   1093                 2_key_the_encryption_to
# 4        3    830                  3_were_armenian_of_the
# ..     ...    ...                                     ...
# 127    126     11           126_network_windows_files_lan
# 128    127     10    127_contains_tune_clementine_darling
# 129    128     10  128_needles_acupuncture_needle_syringe
# 130    129     10         129_sound_stereo_soundbase_mono
# 131    130     10   130_rayshade_rendering_raytracing_pov
#
#                                         Representation  \
# 0       [the, to, and, of, is, for, in, it, that, you]
# 1    [game, team, he, games, players, season, hocke...
# 2      [god, that, of, is, not, to, the, in, and, you]
# ...

# %% [markdown]
# # 8. 임의의 문서에 대한 예측

# %%
new_doc = docs[0]
print(new_doc)
# Out:
# I am sure some bashers of Pens fans are pretty confused about the lack
# of any kind of posts about the recent Pens massacre of the Devils. Actually,
# I am  bit puzzled too and a bit relieved. However, I am going to put an end
# to non-PIttsburghers' relief with a bit of praise for the Pens. Man, they
# are killing those Devils worse than I thought. Jagr just showed you why
# he is much better than his regular season stats. He is also a lot
# fo fun to watch in the playoffs. Bowman should let JAgr have a lot of
# fun in the next couple of games since the Pens are going to beat the pulp out of Jersey anyway. I was very disappointed not to see the Islanders lose the final
# regular season game.          PENS RULE!!!

# %%
topics, probs = model.transform([new_doc])

# %%
print('예측한 토픽 번호 :', topics)
# Out:
# 예측한 토픽 번호 : [np.int64(0)]

# %% [markdown]
# # 9. 모델 저장과 로드

# %%
model.save("my_topics_model")
BerTopic_model = BERTopic.load("my_topics_model")
# Out:
# 2025-08-07 01:03:10,524 - BERTopic - WARNING: When you use `pickle` to save/load a BERTopic model,please make sure that the environments in which you saveand load the model are **exactly** the same. The version of BERTopic,its dependencies, and python need to remain the same.
